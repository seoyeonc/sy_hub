# %% [markdown]
# # Study for Spaces
#
# SEOYEON CHOI
# 2022-12-31
#
# > Spaces
#
# <figure>
# <img
# src="attachment:2022-12-31-Space-study_files/figure-ipynb/b9adcaa0-0671-433c-923a-3e56b0ada3ca-1-6c0d774e-83b1-4f54-809e-01f79d38bafa.png"
# alt="image.png" />
# <figcaption aria-hidden="true">image.png</figcaption>
# </figure>
#
# ## 내적공간
#
# $$|a||b| \cos \theta$$
#
# -   길이 + 각의 개념
#
# Projection
#
# ## 바나흐공간
#
# $$|---|$$
#
# -   길이 + 극한의 개념
#
# ## 노름공간
#
# $$|   |$$
#
# -   길이의 개념
#
# ## 힐베르트공간(유클리드 + 비유클리드 모두 존재)
#
# 퓨리에 해석 - 길이 + 각 + 극한의 개념
