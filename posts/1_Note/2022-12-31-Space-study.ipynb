# %% [raw]
# ---
# title: "Study for Spaces"
# author: "SEOYEON CHOI"
# date: "2022-12-31"
# categories:
#   - Spaces
# ---

# %% [markdown]
# > Spaces

# %% [markdown]
# ![image.png](attachment:6c0d774e-83b1-4f54-809e-01f79d38bafa.png)

# %% [markdown]
# ## 내적공간

# %% [markdown]
# $$|a||b| \cos \theta$$

# %% [markdown]
# - 길이 + 각의 개념
#
# Projection

# %% [markdown]
# ## 바나흐공간

# %% [markdown]
# $$|---|$$

# %% [markdown]
# - 길이 + 극한의 개념

# %% [markdown]
# ## 노름공간

# %% [markdown]
# $$|   |$$

# %% [markdown]
# - 길이의 개념

# %% [markdown]
# ## 힐베르트공간(유클리드 + 비유클리드 모두 존재)

# %% [markdown]
# 퓨리에 해석
# - 길이 + 각 + 극한의 개념
